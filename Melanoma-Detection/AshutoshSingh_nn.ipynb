# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path('/content/gdrive/My Drive/Colab Notebooks/data/Train')
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Colab Notebooks/data/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2244
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 2244 files belonging to 9 classes.
# Using 1796 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 2244 files belonging to 9 classes.
# Using 448 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
num_classes = len(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(15, 15))

for images, labels in train_ds.take(1):
    for i in range(len(class_names)):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis('off')

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
from keras.layers import  Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization

normalization = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
layer = tf.keras.layers.experimental.preprocessing.CategoryEncoding(num_tokens=9, output_mode="one_hot")

train_ds = train_ds.map(lambda x, y: (normalization(x), layer(y)))
val_ds = val_ds.map(lambda x, y: (normalization(x), layer(y)))

# %%
### Your code goes here


model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(180, 180, 3), activation='relu'))

model.add(Conv2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))

model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dense(9))
model.add(Activation('softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 88, 88, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 88, 88, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 88, 88, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 44, 44, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 123904)            0
#
#  dense (Dense)               (None, 256)               31719680
#
#  activation (Activation)     (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_2 (Dense)             (None, 9)                 1161
#
#  activation_2 (Activation)   (None, 9)                 0
#
# =================================================================
# Total params: 31,819,305
# Trainable params: 31,819,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 210s 909ms/step - loss: 2.2510 - accuracy: 0.2233 - val_loss: 1.9632 - val_accuracy: 0.2366
# Epoch 2/20
# 57/57 [==============================] - 9s 159ms/step - loss: 1.9178 - accuracy: 0.2745 - val_loss: 1.8885 - val_accuracy: 0.3036
# Epoch 3/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.9006 - accuracy: 0.3018 - val_loss: 1.8894 - val_accuracy: 0.3013
# Epoch 4/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.8189 - accuracy: 0.3330 - val_loss: 1.7717 - val_accuracy: 0.3125
# Epoch 5/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.7234 - accuracy: 0.3725 - val_loss: 1.6431 - val_accuracy: 0.3906
# Epoch 6/20
# 57/57 [==============================] - 9s 157ms/step - loss: 1.6214 - accuracy: 0.4248 - val_loss: 1.5096 - val_accuracy: 0.4442
# Epoch 7/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.4589 - accuracy: 0.4855 - val_loss: 1.4958 - val_accuracy: 0.4487
# Epoch 8/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.3806 - accuracy: 0.5290 - val_loss: 1.6433 - val_accuracy: 0.4353
# Epoch 9/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.2678 - accuracy: 0.5535 - val_loss: 1.6074 - val_accuracy: 0.4665
# Epoch 10/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.1600 - accuracy: 0.5952 - val_loss: 1.5944 - val_accuracy: 0.4777
# Epoch 11/20
# 57/57 [==============================] - 9s 158ms/step - loss: 1.0519 - accuracy: 0.6409 - val_loss: 1.5812 - val_accuracy: 0.5134
# Epoch 12/20
# 57/57 [==============================] - 9s 158ms/step - loss: 0.9699 - accuracy: 0.6676 - val_loss: 2.1246 - val_accuracy: 0.3929
# Epoch 13/20
# 57/57 [==============================] - 9s 158ms/step - loss: 0.8761 - accuracy: 0.6876 - val_loss: 1.7667 - val_accuracy: 0.4509
# Epoch 14/20
# 57/57 [==============================] - 9s 159ms/step - loss: 0.7938 - accuracy: 0.7183 - val_loss: 2.3996 - val_accuracy: 0.4710
# Epoch 15/20
# 57/57 [==============================] - 10s 168ms/step - loss: 0.7086 - accuracy: 0.7455 - val_loss: 2.4881 - val_accuracy: 0.4375
# Epoch 16/20
# 57/57 [==============================] - 9s 158ms/step - loss: 0.5006 - accuracy: 0.8185 - val_loss: 2.4912 - val_accuracy: 0.4442
# Epoch 17/20
# 57/57 [==============================] - 9s 159ms/step - loss: 0.4699 - accuracy: 0.8408 - val_loss: 2.3602 - val_accuracy: 0.4598
# Epoch 18/20
# 57/57 [==============================] - 9s 160ms/step - loss: 0.3587 - accuracy: 0.8697 - val_loss: 2.5655 - val_accuracy: 0.4353
# Epoch 19/20
# 57/57 [==============================] - 9s 158ms/step - loss: 0.2944 - accuracy: 0.8898 - val_loss: 3.2234 - val_accuracy: 0.4375
# Epoch 20/20
# 57/57 [==============================] - 9s 159ms/step - loss: 0.2880 - accuracy: 0.9026 - val_loss: 3.4084 - val_accuracy: 0.3906

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
# ### Findings
#
# #### Models works on training set very well but fails on validation set. Accurancy on validation set is way less than validation set which is a clear case of Overfitting.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal',
                      input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here


model2 = Sequential()
model2.add(Conv2D(32, (3, 3), input_shape=(180, 180, 3), activation='relu'))

model2.add(Activation('relu'))
model2.add(Conv2D(64, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))


model2.add(Conv2D(64, (3, 3)))
model2.add(Activation('relu'))
model2.add(Conv2D(128, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.2))

model2.add(Conv2D(64, (3, 3)))
model2.add(Activation('relu'))
model2.add(Conv2D(32, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))


model2.add(Flatten())
model2.add(Dense(256))
model2.add(Activation('relu'))

model2.add(Dense(128))
model2.add(Activation('relu'))
model2.add(Dropout(0.2))
model2.add(Dense(9))
model2.add(Activation('softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 178, 178, 32)      896
#
#  activation_3 (Activation)   (None, 178, 178, 32)      0
#
#  conv2d_5 (Conv2D)           (None, 176, 176, 64)      18496
#
#  activation_4 (Activation)   (None, 176, 176, 64)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 88, 88, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 86, 86, 64)        36928
#
#  activation_5 (Activation)   (None, 86, 86, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 84, 84, 128)       73856
#
#  activation_6 (Activation)   (None, 84, 84, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 42, 42, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 42, 42, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 40, 40, 64)        73792
#
#  activation_7 (Activation)   (None, 40, 40, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 38, 38, 32)        18464
#
#  activation_8 (Activation)   (None, 38, 38, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 19, 19, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 11552)             0
#
#  dense_3 (Dense)             (None, 256)               2957568
#
#  activation_9 (Activation)   (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_10 (Activation)  (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
#  activation_11 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 3,214,057
# Trainable params: 3,214,057
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20

history2 = model2.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 17s 245ms/step - loss: 2.0543 - accuracy: 0.1921 - val_loss: 2.0235 - val_accuracy: 0.2054
# Epoch 2/20
# 57/57 [==============================] - 13s 229ms/step - loss: 2.0170 - accuracy: 0.2027 - val_loss: 2.0068 - val_accuracy: 0.2433
# Epoch 3/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.8478 - accuracy: 0.3235 - val_loss: 1.6663 - val_accuracy: 0.4353
# Epoch 4/20
# 57/57 [==============================] - 13s 229ms/step - loss: 1.6611 - accuracy: 0.4042 - val_loss: 1.5370 - val_accuracy: 0.4420
# Epoch 5/20
# 57/57 [==============================] - 13s 229ms/step - loss: 1.6301 - accuracy: 0.4081 - val_loss: 1.6053 - val_accuracy: 0.4040
# Epoch 6/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.5699 - accuracy: 0.4354 - val_loss: 1.5308 - val_accuracy: 0.4598
# Epoch 7/20
# 57/57 [==============================] - 13s 229ms/step - loss: 1.5444 - accuracy: 0.4543 - val_loss: 1.5924 - val_accuracy: 0.4420
# Epoch 8/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.4757 - accuracy: 0.4727 - val_loss: 1.4756 - val_accuracy: 0.4955
# Epoch 9/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.4797 - accuracy: 0.4705 - val_loss: 1.6263 - val_accuracy: 0.4464
# Epoch 10/20
# 57/57 [==============================] - 13s 229ms/step - loss: 1.4100 - accuracy: 0.5078 - val_loss: 1.5775 - val_accuracy: 0.4777
# Epoch 11/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.3819 - accuracy: 0.5161 - val_loss: 1.5281 - val_accuracy: 0.5134
# Epoch 12/20
# 57/57 [==============================] - 13s 231ms/step - loss: 1.3589 - accuracy: 0.5256 - val_loss: 1.5938 - val_accuracy: 0.5067
# Epoch 13/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.3357 - accuracy: 0.5329 - val_loss: 1.5951 - val_accuracy: 0.4598
# Epoch 14/20
# 57/57 [==============================] - 13s 227ms/step - loss: 1.3184 - accuracy: 0.5284 - val_loss: 1.6409 - val_accuracy: 0.4732
# Epoch 15/20
# 57/57 [==============================] - 13s 227ms/step - loss: 1.2312 - accuracy: 0.5523 - val_loss: 1.5937 - val_accuracy: 0.5022
# Epoch 16/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.2338 - accuracy: 0.5612 - val_loss: 1.6382 - val_accuracy: 0.4643
# Epoch 17/20
# 57/57 [==============================] - 13s 227ms/step - loss: 1.2555 - accuracy: 0.5518 - val_loss: 1.6093 - val_accuracy: 0.5112
# Epoch 18/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.1586 - accuracy: 0.5807 - val_loss: 2.1989 - val_accuracy: 0.4978
# Epoch 19/20
# 57/57 [==============================] - 13s 228ms/step - loss: 1.1236 - accuracy: 0.5958 - val_loss: 1.6998 - val_accuracy: 0.4955
# Epoch 20/20
# 57/57 [==============================] - 13s 227ms/step - loss: 1.1426 - accuracy: 0.5841 - val_loss: 2.0593 - val_accuracy: 0.4754

# %% [markdown]
# ### Visualizing the results

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']

loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# Training and validation accuracy is very less  which means model has not learned and it is case of underfiting now.  There is no improvement in model.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
count = {}

for i in class_names:
    count[i] = len(list(data_dir_train.glob(f'{i}/*.jpg')))

count = dict(sorted(count.items(), key=lambda x: x[1]))

count_list = list(count.items())
x, y = zip(*count_list)

plt.figure(figsize=(12, 8))
plt.barh(x, y)
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# * Seborrheic Keratosis
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# * Pigmented Benign Keratosis

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/My Drive/Colab Notebooks/data/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F3C6599B990>: 100%|██████████| 500/500 [00:23<00:00, 21.47 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3C66339150>: 100%|██████████| 500/500 [00:26<00:00, 18.75 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3C662F3210>: 100%|██████████| 500/500 [00:27<00:00, 18.17 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1536 at 0x7F3CD0107810>: 100%|██████████| 500/500 [02:02<00:00,  4.09 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3C65F0CBD0>: 100%|██████████| 500/500 [01:47<00:00,  4.66 Samples/s]
# Initialised with 467 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3C65E6BFD0>: 100%|██████████| 500/500 [00:24<00:00, 20.77 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F3C66318CD0>: 100%|██████████| 500/500 [00:50<00:00,  9.94 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3C65960F10>: 100%|██████████| 500/500 [00:22<00:00, 22.66 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Colab Notebooks/data/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F3D7540F250>: 100%|██████████| 500/500 [00:22<00:00, 22.02 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list[0]
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data/Train/squamous cell carcinoma/output/squamous cell carcinoma_original_ISIC_0030986.jpg_8ec5ce65-7aa3-4eff-b11d-3031b50f55a8.jpg'

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
print(list(set(lesion_list_new)))
# Out:
# ['basal cell carcinoma', 'actinic keratosis', 'squamous cell carcinoma', 'melanoma', 'dermatofibroma', 'nevus', 'vascular lesion', 'seborrheic keratosis', 'pigmented benign keratosis']

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*', 'output', '*.jpg'))]
dataframe_dict = dict(zip(path_list_new, lesion_list_new))

# %%
original_df = pd.DataFrame(list(dataframe_dict.items()), columns=['Path', 'Label'])
original_df['Label'].value_counts()
# Out:
# squamous cell carcinoma       500
# vascular lesion               500
# dermatofibroma                500
# melanoma                      500
# actinic keratosis             500
# seborrheic keratosis          500
# basal cell carcinoma          500
# nevus                         500
# pigmented benign keratosis    500
# Name: Label, dtype: int64

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# squamous cell carcinoma       1000
# vascular lesion               1000
# dermatofibroma                1000
# melanoma                      1000
# actinic keratosis             1000
# seborrheic keratosis          1000
# basal cell carcinoma          1000
# nevus                         1000
# pigmented benign keratosis    1000
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/gdrive/My Drive/Colab Notebooks/data/Train/"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6744 files belonging to 9 classes.
# Using 5396 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6744 files belonging to 9 classes.
# Using 1348 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalization = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
layer = tf.keras.layers.experimental.preprocessing.CategoryEncoding(num_tokens=9, output_mode="one_hot")

train_ds = train_ds.map(lambda x, y: (normalization(x), layer(y)))
val_ds = val_ds.map(lambda x, y: (normalization(x), layer(y)))

model3 = Sequential( 
    [layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1)])

## simple model works better with more data

model3.add(Conv2D(16, 3, padding='same'))
model3.add(Activation('relu'))
model3.add(MaxPooling2D())

model3.add(Conv2D(32, 3, padding='same'))
model3.add(Activation('relu'))
model3.add(MaxPooling2D())

model3.add(Conv2D(64, 3, padding='same'))
model3.add(Activation('relu'))
model3.add(MaxPooling2D())
model3.add(Dropout(0.20))

model3.add(Flatten())
model3.add(Dense(128))
model3.add(Activation('relu'))
model3.add(Dense(9))
model3.add(Activation('softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model3.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history3 = model3.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epoch
# Epoch 41/50
# 169/169 [==============================] - 10s 57ms/step - loss: 0.2688 - accuracy: 0.8986 - val_loss: 0.5133 - val_accuracy: 0.8717
# Epoch 42/50
# 169/169 [==============================] - 10s 56ms/step - loss: 0.2530 - accuracy: 0.9029 - val_loss: 0.4815 - val_accuracy: 0.8665
# Epoch 43/50
# 169/169 [==============================] - 10s 57ms/step - loss: 0.2587 - accuracy: 0.8992 - val_loss: 0.5715 - val_accuracy: 0.8234
# Epoch 44/50
# 169/169 [==============================] - 10s 59ms/step - loss: 0.2651 - accuracy: 0.8955 - val_loss: 0.4923 - val_accuracy: 0.8568
# Epoch 45/50
# 169/169 [==============================] - 10s 56ms/step - loss: 0.2511 - accuracy: 0.9066 - val_loss: 0.5082 - val_accuracy: 0.8702
# Epoch 46/50
# 169/169 [==============================] - 10s 57ms/step - loss: 0.2729 - accuracy: 0.8994 - val_loss: 0.4639 - val_accuracy: 0.8531
# Epoch 47/50
# 169/169 [==============================] - 10s 60ms/step - loss: 0.2656 - accuracy: 0.8966 - val_loss: 0.4934 - val_accuracy: 0.8657
# Epoch 48/50
# 169/169 [==============================] - 10s 57ms/step - loss: 0.2271 - accuracy: 0.9097 - val_loss: 0.5009 - val_accuracy: 0.8576
# Epoch 49/50
# 169/169 [==============================] - 10s 59ms/step - loss: 0.2771 - accuracy: 0.8918 - val_loss: 0.4701 - val_accuracy: 0.8628
# Epoch 50/50
# 169/169 [==============================] - 10s 57ms/step - loss: 0.2490 - accuracy: 0.9047 - val_loss: 0.5046 - val_accuracy: 0.8605

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history3.history['accuracy']
val_acc = history3.history['val_accuracy']

loss = history3.history['loss']
val_loss = history3.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# After rebalancing of the class the accuracy on the validation set has shown major improvement, the validation set now shows 86.6% accuracy. This confirms that class rebalance helped in dealing with the underfitting that was present after using dropouts to deal with overfitting.

# %% [markdown]
# # Model Performance on test dataset

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    seed = 123,
    image_size = (img_height,img_width),
    batch_size = batch_size,
    color_mode='rgb'
)
# Out:
# Found 118 files belonging to 9 classes.

# %%
test_ds = test_ds.map(lambda x, y: (normalization(x), layer(y)))

# %%
loss , accuracy = model3.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 22s 91ms/step - loss: 6.8598 - accuracy: 0.4153

# %% [markdown]
# ## Prediction on New Test Data

# %%
y_pred= model3.fit(test_ds)
# Out:
# 4/4 [==============================] - 4s 107ms/step - loss: 6.3402 - accuracy: 0.3814

# %%
img_path = "/content/gdrive/My Drive/Colab Notebooks/data/Test/melanoma/ISIC_0000056.jpg"

img = tf.keras.utils.load_img(
    img_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model3.predict(img_array)
score = tf.nn.softmax(predictions)

print(score)
# Out:
# tf.Tensor(
# [[0.09329855 0.09329855 0.09329855 0.2536117  0.09329855 0.09329855
#   0.09329855 0.09329855 0.09329855]], shape=(1, 9), dtype=float32)

# %%
class_names[np.argmax(score)]
# Out:
# 'melanoma'
